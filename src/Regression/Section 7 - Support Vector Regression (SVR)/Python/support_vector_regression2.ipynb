# %% [markdown]
# # サポートベクトル回帰(SVR)

# %% [markdown]
# ## ライブラリのインポート

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## データセットのインポート

# %%
dataset = pd.read_csv('svr.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
print(X)
# Out:
# [[1]
#  [1]
#  [1]
#  [1]
#  [2]
#  [2]
#  [2]
#  [3]
#  [3]
#  [4]
#  [4]
#  [4]
#  [5]
#  [5]
#  [5]
#  [5]]

# %%
print(y)
# Out:
# [2 3 4 5 3 4 5 4 5 4 5 6 4 5 6 7]

# %%
y = y.reshape(len(y),1)

# %%
print(y)
# Out:
# [[2]
#  [3]
#  [4]
#  [5]
#  [3]
#  [4]
#  [5]
#  [4]
#  [5]
#  [4]
#  [5]
#  [6]
#  [4]
#  [5]
#  [6]
#  [7]]

# %% [markdown]
# ## フィーチャースケーリング

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

# %%
print(X)
# Out:
# [[-1.29777137]
#  [-1.29777137]
#  [-1.29777137]
#  [-1.29777137]
#  [-0.64888568]
#  [-0.64888568]
#  [-0.64888568]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.64888568]
#  [ 0.64888568]
#  [ 0.64888568]
#  [ 1.29777137]
#  [ 1.29777137]
#  [ 1.29777137]
#  [ 1.29777137]]

# %%
print(y)
# Out:
# [[-2.04124145]
#  [-1.22474487]
#  [-0.40824829]
#  [ 0.40824829]
#  [-1.22474487]
#  [-0.40824829]
#  [ 0.40824829]
#  [-0.40824829]
#  [ 0.40824829]
#  [-0.40824829]
#  [ 0.40824829]
#  [ 1.22474487]
#  [-0.40824829]
#  [ 0.40824829]
#  [ 1.22474487]
#  [ 2.04124145]]

# %% [markdown]
# ## データセットを使ったモデルの訓練

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'linear', epsilon=0.5)
regressor.fit(X, y)
# Out:
# D:\Runtime\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR(epsilon=0.5, kernel='linear')

# %% [markdown]
# ## 結果の可視化

# %%
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(sc_X.inverse_transform(X), sc_y.inverse_transform(regressor.predict(X)), color = 'blue')
plt.show()
# Out:
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.
